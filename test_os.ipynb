# %%
import os
import random
import shutil

# %%
wham_root = r"/home/ovistetom/Documents/Databases_Local/LIBRIMIX/wham_noise"  # 60000 + 5000 + 3000 files

# %%
def parse_lisp(lisp_root, subset='trn'):
    """Parse database and return shuffled list of all files in the given subset."""
    lisp_path = os.path.join(lisp_root, subset)
    file_list = []

    for file_name in os.listdir(lisp_path):
        file_path = os.path.join(lisp_path, file_name)
        file_list.append(file_path)
            
    print(f"Found {len(file_list)} files in '{lisp_path}'.")
    random.shuffle(file_list)
    return file_list

# %%
x = parse_wham(wham_root)
# Out:
# Found 60000 files in '/home/ovistetom/Documents/Databases_Local/LIBRIMIX/wham_noise/tr'.

# %%
librispeech_root = r"/home/ovistetom/Documents/Databases_Local/LIBRIMIX/LibriSpeech"

# %%
list_of_all_samples = []
for dirpath, dirnames, filenames in x:
    if not os.path.basename(dirpath) == 'metadata':
        for filename in filenames 
        list_of_all_samples.append(os.path.join(dirpath))

# %%
dirnames

# %%
filenames
